# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
#히스토그램을 그린다.
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"])
ax.set_title("Total Bill Histogram with Density Plot")
# Out:
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
#distplot메서드를 사용하면 히스토그램과 밀집도 그래프를 같이 그린다. 
#만약 밀집도 그래프를 제외하고 싶다면 kde인자값을 False로 지정하면 된다. 
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"], kde=False)
ax.set_title("Total Bill Histogram")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#밀집도 그래프만 나타내려면 hist인자를 False로 지정하면 됩니다. 
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"], hist=False)
ax.set_title("Total Bill Density")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Unit Probability")
# Out:
# Text(0, 0.5, 'Unit Probability')

# %%
#실무 환경에서는 데이터 시각화를 더 효율적으로 하기 위해 여러 그래프를 
#한번에 출력하는 경우가 많다. 다음은 히스토그램과 밀집도를 그리는 
#distplot메서드에 rug인자를 추가하여 양탄자(rug)그래프까지 그린 것이다. 
#양탄자 그래프는 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 
#정도를 표현한 그래프이다.
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"], rug=True)
ax.set_title("Total Bill Histogram with Density and Rug plot")
ax.set_xlabel("Total Bill")
# Out:
# Text(0.5, 0, 'Total Bill')

# %%
#이번에는 히스토그램과 비슷하게 생긴 count그래프를 그려본다. 
#count그래프는 이산값을 나타낸 그래프이다. 
ax = plt.subplots()
ax = sns.countplot("day", data=tips)
ax.set_title("Count of days")
ax.set_xlabel("Day of Week")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#seaborn라이브러리로 산점도 그래프 그리기 
#산점도 그래프를 그리려면 seaborn라이브러리의 regplot메서드를 사용해야 한다. 
#regplot메서드를 사용하면 산점도 그래프와 회귀선을 함께 그릴 수 있다. 
#만약 회귀선을 제거하려면 fit_reg인자를 False로 지정하면 된다. 
ax = plt.subplots()
ax = sns.regplot(x="total_bill", y="tip", data=tips)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x="total_bill", y="tip", data=tips, fit_reg=False)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
#이번에는 산점도 그래프와 히스토그램을 한번에 그려주는 jointplot메서드를 사용해본다. 
#x,y인자에 원하는 열 이름을 지정하고 data인자값으로 데이터프레임을 지정하면 그래프를 
#그릴 수 있다. 
joint = sns.jointplot(x="total_bill", y="tip", data=tips)
joint.set_axis_labels(xlabel="Total Bill", ylabel="Tip")
joint.fig.suptitle("Joint Plot of Total Bill and TIp", fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and TIp')

# %%
#산점도 그래프는 점이 겹쳐 보일 경우 점을 구분하기 어렵다는 단점이 있다.
#이런 경우 육각 그래프(hexbin)을 사용하면 된다. 
#특정 데이터의 수가 많아지면 점점 진한 색으로 표현된다. 
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
hexbin.set_axis_labels(xlabel="Total Bill", ylabel="Tip")
hexbin.fig.suptitle("Hexbin Joint Plot of Total Bill and TIp", fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and TIp')

# %%
#이차원 밀집도 그리기 
#이차원 밀집도는 kdeplot메서드로 만들 수 있다. 
#다음은 total_bill, tip열 데이터를 전달하여 이차원 밀집도를 그린 것이다. 
#이때 shade인자값을 True로 지정하면 그래프에 음영효과를 줄 수 있다.
ax = plt.subplots()
ax = sns.kdeplot(data=tips["total_bill"],
                data2=tips["tip"],
                shade=True)
ax.set_title("Kernel Density Plot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
#바 그래프 그리기 
#바 그래프는 지정한 변수의 평균을 계산하여 그릴 수 있다. 
#다음은 시간에 따라 지불한 비용의 평균을 바 그래프로 그린것 
ax = plt.subplots()
ax = sns.barplot(x="time", y="total_bill", data=tips)
ax.set_xlabel("Time of day")
ax.set_ylabel("Average total bill")
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
#박스 그래프 그리기
#박스 그래프는 최소값, 1분위수, 중간값, 3분위수, 최대값, 이상치등 다양한 
#통계량을 한번에 표현하는 그래프입니다.
ax = plt.subplots()
ax = sns.boxplot(x="time", y="total_bill", data=tips)
ax.set_title("Boxplot of total bill by time of day")
ax.set_xlabel("Time od day")
ax.set_ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#박스 그래프는 다양한 통계 수치를 확인하기 위해 자주 사용하는 그래프이지만 
#데이터 분산이 모호하게 표현됩니다. 이런 경우에는 박스 그래프에 커널 밀도를 추정한
#바이올린 그래프를 사용하면 됩니다. 
#바이올린 그래프는 violinplot메서드를 사용하여 그릴 수 있습니다.
ax = plt.subplots()
ax = sns.violinplot(x="time", y="total_bill", data=tips)
ax.set_title("Violin plot of total bill by tiime of day")
ax.set_xlabel("Time of day")
ax.set_ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#관계 그래프를 그려본다. 관계 그래프는 지금까지 설명한 그래프를 종합한 그래프이다. 
#관계 그래프는 pairplot메서드에 데이터프레임을 넣는 방법으로 간단하게 그릴 수 있다. 
fig = sns.pairplot(tips)

# %%
#이때 관계 그래프는 중복된 정보가 표현된다는 단점이 있다. 
#즉 관계 그래프의 절반(대각선을 기준으로 위)은 나머지 절반(대각선을 기준으로
#아래)과 같다. 이런 경우에는 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는
#그래프로 교체하면 된다. 
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()

# %%
#다변량 그래프 그리기
#이번에는 seaborn라이브러리로 다변량 그래프를 그려본다. 
#바이올린 그래프를 그리되 색상을 추가한다. hue인자값으로 색상에 사용할 열 이름을
#추가한다.
ax = plt.subplots()
ax = sns.violinplot(x="time", y="total_bill", hue="sex",
                   data=tips, split=True)

# %%
#산점도, 관계 그래프 그리기. 색상 추가
scatter = sns.lmplot(x="total_bill", y="tip", 
                    data=tips, hue="sex", fit_reg=False)

# %%
fig = sns.pairplot(tips, hue="sex")

# %%
#산점도 그래프의 크기와 모양 조절하기
#산점도 그래프의 점 크기를 조절하려면 scatter_kws에 딕셔너리 형태로 인자값을
#전달하면 된다. 여기서는 크기만 조절하기 위해 "s":tips["size"]를 딕셔너리에
#담아 전달했다.
scatter = sns.lmplot(x="total_bill", y="tip", data=tips,
                    fit_reg=False, hue="sex",
                     scatter_kws={"s": tips["size"]*20})

# %%
#만약 산점도 그래프의 점을 다른 기호로 표현하고 싶다면 markers인자값에 표현하고자
#하는 기호를 리스트에 담아 전달하면 된다.
scatter = sns.lmplot(x="total_bill", y="tip", data=tips, fit_reg=False, 
                    hue="sex", markers=["o","x"],
                    scatter_kws={"s":tips["size"]*10})

# %%
#앤스콤 4분할 그래프를 Implot메서드로 그린다. x와 y인자에는 앤스콤 데이터 집합의
#x,y열을 전달하고 data인자에는 데이터프레임(anscombe)을 전달했다. 
anscombe_plot = sns.lmplot(x="x", y="y", data=anscombe,
                          fig_reg=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4125f2e9eb21> in <module>
#       1 #앤스콤 4분할 그래프를 Implot메서드로 그린다. x와 y인자에는 앤스콤 데이터 집합의
#       2 #x,y열을 전달하고 data인자에는 데이터프레임(anscombe)을 전달했다.
# ----> 3 anscombe_plot = sns.lmplot(x="x", y="y", data=anscombe,
#       4                           fig_reg=False)
#
# NameError: name 'anscombe' is not defined

# %%
#FacetGrid클래스로도 그룹별 그래프를 그릴 수 있다. 
facet = sns.FacetGrid(tips, col="time")
facet.map(sns.distplot, "total_bill", rug=True)

# %%
#다변량 그래프도 그린다. 다음은 tips데이터집합의 day열로 그룹을 구분하여
#그래프를 그린 것이다.
facet = sns.FacetGrid(tips, col="day", hue="sex")
facet = facet.map(plt.scatter, "total_bill", "tip")
facet = facet.add_legend()

# %%
#이번에는 더 많은 변수를 사용하여 그래프를 그려본다. 
#다음은 time, smoker열을 사용항려 산점도 그래프를 그린 것이다. 
facet = sns.FacetGrid(tips, col="time", row="smoker", hue="sex")
facet.map(plt.scatter, "total_bill", "tip")

# %%
#DataFrame과 Series로도 그래프 그리기
#히스토그램 그리기 
ax = plt.subplots()
ax = tips["total_bill"].plot.hist()

# %%
#투명도를 조절하는 경우 alpha를 사용한다
fig, ax = plt.subplots()
ax = tips[["total_bill", "tip"]].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
ax = plt.subplots()
ax = tips["tip"].plot.kde()

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x="total_bill", y="tip", ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x="total_bill", y="tip", ax=ax)

# %%
#이때 육각 그래프의 육각형 크기는 gridsize인자를 사용해서 변경할 수 있다.
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x="total_bill", y="tip", gridsize=10, ax=ax)

# %%
#box메서드를 사용한 박스 그래프
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %%
#seaborn라이브러리로 그래프 스타일 설정하기
fig, ax = plt.subplots()
ax = sns.violinplot(x="time", y="total_bill", hue="sex",
                   data=tips, split=True)

# %%
#whitegrid로 스타일을 설정하여 그래프를 그린다. 
sns.set_style("whitegrid")
fig, ax = plt.subplots()
ax = sns.violinplot(x="time", y="total_bill", hue="sex", data=tips, split=True)

# %%
#for문을 사용해서 모든 스타일을 하나씩 적용한 경우
fig = plt.figure()
seaborn_styles = ["darkgrid", "whitegrid","dark","white","ticks"]

for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1 
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x="time", y="total_bill", data=tips, ax=ax)
        violin.set_title(style)
        
fig.tight_layout()
